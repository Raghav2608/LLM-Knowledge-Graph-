# %%
from data_ingestion.arxiv.arxiv_pipeline import ArXivDataIngestionPipeline

data_ingestion = ArXivDataIngestionPipeline()
entries = data_ingestion.fetch_entries("Meta Learning Using Domain Generalization",max_results=100)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(entries.keys())
#
# AttributeError: 'list' object has no attribute 'keys'
